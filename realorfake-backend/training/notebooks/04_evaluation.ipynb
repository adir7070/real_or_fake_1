# %% [markdown]
# # 04 — Evaluation & Visualization
# Confusion matrix, ROC curve, Grad-CAM examples, cross-generator tests.

# %%
# !python training/scripts/evaluate.py \
    --checkpoint models/best_model.pth \
    --data-root data/cifake \
    --arch vit_b_16 \
    --out-dir models

# %%
import matplotlib.pyplot as plt
from PIL import Image

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].imshow(Image.open('models/confusion_matrix.png'))
axes[0].axis('off')
axes[0].set_title('Confusion Matrix')
axes[1].imshow(Image.open('models/roc_curve.png'))
axes[1].axis('off')
axes[1].set_title('ROC Curve')
plt.tight_layout()
plt.show()
