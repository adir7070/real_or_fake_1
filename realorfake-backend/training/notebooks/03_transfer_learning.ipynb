# %% [markdown]
# # 03 — Transfer Learning (EfficientNet & ViT)
# Fine-tune pretrained ImageNet models for AI image detection.

# %%
# EfficientNet
# !python training/scripts/train.py \
    --config training/configs/efficientnet.yaml \
    --data-root data/cifake \
    --out-dir models/efficientnet

# %%
# ViT
# !python training/scripts/train.py \
    --config training/configs/vit.yaml \
    --data-root data/cifake \
    --out-dir models
