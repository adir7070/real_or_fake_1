# %% [markdown]
# # 02 — Baseline CNN
# Train and evaluate the from-scratch CNN baseline.

# %%
# Run training
# !python training/scripts/train.py \
    --config training/configs/baseline.yaml \
    --data-root data/cifake \
    --out-dir models/baseline
